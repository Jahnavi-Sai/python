# %% [markdown]
# # DataTypes
# ![Basic-Data-Types-in-Python_Watermarked.webp](attachment:82884f91-ec0f-4e4f-8e4a-0b86d75abd36.webp)
#
# integer-int (eg:1,34,2456,-65)
#
# float (eg: 34.2, 2.1)
#
# complex (eg: a+bj,10+20j,6-5j)
#
# boolean-bool (eg: True, False)
#
# string- str (eg:1,23,'chanu',"chintu")

# %% [markdown]
# # String
# A string is a sequence of characters. Python treats anything inside quotes as a string. This includes letters, numbers, and symbols.
#
# A string could a stingle or double quotes (' '," ")

# %%
letter1='chanu'
print(letter1)
# Out:
# chanu

# %%
print(len(letter1))
# Out:
# 5

# %%
type(letter1)
# Out:
# str

# %%
sent="I love cats and dogs"
print(sent)
# Out:
# I love cats and dogs

# %% [markdown]
# Multiline quotes

# %%
mult_str='''In my house totally 4 cats and 1 dog is their. 
the names are chanu,chikki,chintu,chinni and ramu.
I always enjoy by seeing and playing with them.''' # the difference between is quotes(''' ''',""" """)
print(mult_str)
# Out:
# In my house totally 4 cats and 1 dog is their.
# the names are chanu,chikki,chintu,chinni and ramu.
# I always enjoy by seeing and playing with them.

# %%
mult_str1="""In my house totally 4 cats and 1 dog is their.
the names are chanu,chikki,chintu,chinni and ramu.
I always enjoy by seeing and playing with them."""
print(mult_str1)
# Out:
# In my house totally 4 cats and 1 dog is their.
# the names are chanu,chikki,chintu,chinni and ramu.
# I always enjoy by seeing and playing with them.

# %% [markdown]
# String Concatenation

# %%
first_name='jahnavi'
last_name='muthyala'
full_name=first_name+ " "+last_name

# %%
print(full_name)
# Out:
# jahnavi muthyala

# %%
g='chanu' # accessing charcaters in string by index
q,w,e,r,t=g
print(q)
print(w)
print(e)
print(r)
print(t)
# Out:
# c
# h
# a
# n
# u

# %% [markdown]
# # Boolean
# boolean variable can have only two values- True or False

# %%
a=True
b=False

# %%
a
# Out:
# True

# %%
b
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
a1=False

# %%
a1
# Out:
# False

# %%
a*a1
# Out:
# 0

# %%
a+b+a1
# Out:
# 1

# %%
q=1
w=0

# %%
q>w
# Out:
# True

# %%
q>w
# Out:
# False

# %% [markdown]
# # Complex
# complex has two values the first one is the real part of the complex number and the second one is the imaginary part of the complex number
#    a+bj
#
#    a= real part
#    b= imaginary part
#    j= root of -1

# %%
c=10+20j

# %%
c
# Out:
# (10+20j)

# %%
print(c.real)
print(c.imag)
# Out:
# 10.0
# 20.0

# %%
c1=21+11j

# %%
c1
# Out:
# (21+11j)

# %%
type(c1)
# Out:
# complex

# %%
c+c1
# Out:
# (31+31j)

# %%
c-c1
# Out:
# (-11+9j)

# %%
c*c1
# Out:
# (-10+530j)

# %%
c2=10+-2.5J

# %%
c2
# Out:
# (10-2.5j)

# %%
c1/c2+c
# Out:
# (11.717647058823529+21.529411764705884j)

# %% [markdown]
# # Float
# Float is a datatyoe which is to store the postive and negative numbers with decimal point .eg: 23.1

# %%
f=10.2

# %%
f
# Out:
# 10.2

# %%
type(f)
# Out:
# float

# %%
f1=1e0
f1
# Out:
# 1.0

# %%
f2=2e1
f2
# Out:
# 20.0

# %%
f3=3e2
f3
# Out:
# 300.0

# %%
e=f+f1*f2
e
# Out:
# 30.2

# %%
type(e)
# Out:
# float

# %% [markdown]
# # Integer
# Integer ia s whole number,positive number,negative number, without decimal, and unlimited length eg: 12,111,142543657673.....

# %%
i=2

# %%
i
# Out:
# 2

# %%
type(i)
# Out:
# int

# %%
2i=6544
# Out:
#   Cell In[132], line 1
#     2i=6544
#     ^
# SyntaxError: invalid decimal literal

# %%
i2=56
i2
# Out:
# 56

# %%
i3=-23
i3
# Out:
# -23

# %%
i+i2+i3
# Out:
# 35

# %%
i*i2+i3-i
# Out:
# 87
