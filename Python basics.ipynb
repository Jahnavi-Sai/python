# %% [markdown]
# # Python
# python is a object oriented programming language and it is highly recommended programming language.
#
# father of python is guidoe vanrosam.
#
# python can run in different platforms like google colab,jupiter notebook, spyder, cmd prompts.
#
# python is very powerful for bid data,data Science,gen ai, llm model and etc.
#
# The main advantage of python is libraries or frameworks. We took the all the concepts from the java , c, c++, c# to create python.

# %% [markdown]
# # IDE-Integrated Development Environment
# In ide the user and developer write the code,run the code, read the code, fix the code.
#
# when we the code we get bugs i.e errors the developer will debug the code by using ide the ide platforms like google colab, spyder, jupiter notebook etc.
#
# python is both interpreter and compiler.
#
# interpreter- excute the code line by line
#
# complier- excute entire code at once

# %% [markdown]
# # Jupiter Notebook in Anaconda
# Anaconda is a distrubted of the python and R programming languages for computing like data science, ml applications etc to aims for simplying packages management and development.
#
# Jupiter notebook is to run the python code in cell formate for easy understanding.

# %% [markdown]
# some basic code

# %%
26+763 #addition
# Out:
# 789

# %%
21+2
# Out:
# 23

# %%
258-25 #subtraction
# Out:
# 233

# %%
8-2
# Out:
# 6

# %%
45/5 #division
# Out:
# 9.0

# %%
6/2
# Out:
# 3.0

# %%
526/5 #float division
# Out:
# 105.2

# %%
45/4
# Out:
# 11.25

# %%
526//5 #int division
# Out:
# 105

# %%
45//4
# Out:
# 11

# %%
6+6-
# Out:
#   Cell In[44], line 1
#     6+6-
#         ^
# SyntaxError: invalid syntax

# %%
6+-6
# Out:
# 0

# %%
52+86-25*3/2
# Out:
# 100.5

# %%
(5*3+9-2/2) #BODMAS (brackets,order,divide,mul,add,sub)
# Out:
# 23.0

# %%
5*5*5*5*5 #exponential
# Out:
# 3125

# %%
5***5
# Out:
#   Cell In[70], line 1
#     5***5
#        ^
# SyntaxError: invalid syntax

# %%
5**5
# Out:
# 3125

# %%
5%3 #modules
# Out:
# 2

# %%
123%5
# Out:
# 3

# %%
45%%2
# Out:
#   Cell In[80], line 1
#     45%%2
#        ^
# SyntaxError: invalid syntax

# %%
5+'chanu'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 5+'chanu'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a=5
b='chanu'
print(a)
print(b)
# Out:
# 5
# chanu

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
a1=chikki # we want specify the string with ' '
b1=chinni
print(a1+b1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 a1=chikki
#       2 b1=chinni
#       3 print(a1+b1)
#
# NameError: name 'chikki' is not defined

# %%
a1='chikki'
b1='chinni'
print(a1+b1)
# Out:
# chikkichinni

# %%
a1=' chikki '
b1=' chinni '
print(a1+b1)
# Out:
#  chikki  chinni

# %%
c1=' chintu '
print(a1+b1+c1)
# Out:
#  chikki  chinni  chintu

# %%
print(a1+b1-c1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 print(a1+b1-c1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
4 * 'chikki' #  without gaps between each word
# Out:
# 'chikkichikkichikkichikki'

# %%
4*' chikki ' # with gaps between each word
# Out:
# ' chikki  chikki  chikki  chikki '

# %%
3*a1
# Out:
# ' chikki  chikki  chikki '

# %%
5* (a,a1,b1,c1)
# Out:
# (5,
#  ' chikki ',
#  ' chinni ',
#  ' chintu ',
#  5,
#  ' chikki ',
#  ' chinni ',
#  ' chintu ',
#  5,
#  ' chikki ',
#  ' chinni ',
#  ' chintu ',
#  5,
#  ' chikki ',
#  ' chinni ',
#  ' chintu ',
#  5,
#  ' chikki ',
#  ' chinni ',
#  ' chintu ')
